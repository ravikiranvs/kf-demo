# %% [markdown]
# ## Install required Python packages

# %%
# !pip install mlflow==2.15.1 kserve==0.13.1 tenacity
# Out:
# Collecting mlflow==2.15.1
#   Downloading mlflow-2.15.1-py3-none-any.whl.metadata (29 kB)
# Collecting kserve==0.13.1
#   Downloading kserve-0.13.1-py3-none-any.whl.metadata (9.1 kB)
# Collecting tenacity
#   Downloading tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting mlflow-skinny==2.15.1 (from mlflow==2.15.1)
#   Downloading mlflow_skinny-2.15.1-py3-none-any.whl.metadata (30 kB)
# Collecting Flask<4 (from mlflow==2.15.1)
#   Downloading flask-3.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting alembic!=1.10.0,<2 (from mlflow==2.15.1)
#   Downloading alembic-1.15.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting docker<8,>=4.0.0 (from mlflow==2.15.1)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow==2.15.1)
#   Downloading graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting markdown<4,>=3.3 (from mlflow==2.15.1)
#   Downloading markdown-3.8-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: matplotlib<4 in /opt/conda/lib/python3.11/site-packages (from mlflow==2.15.1) (3.10.0)
# Requirement already satisfied: numpy<2 in /opt/conda/lib/python3.11/site-packages (from mlflow==2.15.1) (1.26.4)
# Requirement already satisfied: pandas<3 in /opt/conda/lib/python3.11/site-packages (from mlflow==2.15.1) (2.2.3)
# Collecting pyarrow<16,>=4.0.0 (from mlflow==2.15.1)
#   Downloading pyarrow-15.0.2-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Collecting querystring-parser<2 (from mlflow==2.15.1)
#   Downloading querystring_parser-1.2.4-py2.py3-none-any.whl.metadata (559 bytes)
# Requirement already satisfied: scikit-learn<2 in /opt/conda/lib/python3.11/site-packages (from mlflow==2.15.1) (1.6.1)
# Requirement already satisfied: scipy<2 in /opt/conda/lib/python3.11/site-packages (from mlflow==2.15.1) (1.15.1)
# Collecting sqlalchemy<3,>=1.4.0 (from mlflow==2.15.1)
#   Downloading sqlalchemy-2.0.40-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Requirement already satisfied: Jinja2<4,>=2.11 in /opt/conda/lib/python3.11/site-packages (from mlflow==2.15.1) (3.1.5)
# Collecting gunicorn<23 (from mlflow==2.15.1)
#   Downloading gunicorn-22.0.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting cloudevents<2.0.0,>=1.6.2 (from kserve==0.13.1)
#   Downloading cloudevents-1.11.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting fastapi<0.110.0,>=0.109.1 (from kserve==0.13.1)
#   Downloading fastapi-0.109.2-py3-none-any.whl.metadata (25 kB)
# Collecting grpcio<2.0.0,>=1.49.1 (from kserve==0.13.1)
#   Downloading grpcio-1.71.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting httpx<0.27.0,>=0.26.0 (from kserve==0.13.1)
#   Downloading httpx-0.26.0-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: kubernetes>=23.3.0 in /opt/conda/lib/python3.11/site-packages (from kserve==0.13.1) (30.1.0)
# Collecting orjson<4.0.0,>=3.9.15 (from kserve==0.13.1)
#   Downloading orjson-3.10.16-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (41 kB)
# Collecting prometheus-client<0.21.0,>=0.20.0 (from kserve==0.13.1)
#   Downloading prometheus_client-0.20.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting protobuf<4.0.0,>=3.19.0 (from kserve==0.13.1)
#   Downloading protobuf-3.20.3-py2.py3-none-any.whl.metadata (720 bytes)
# Collecting psutil<6.0.0,>=5.9.0 (from kserve==0.13.1)
#   Downloading psutil-5.9.8-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Collecting pydantic<3,>1.0 (from kserve==0.13.1)
#   Downloading pydantic-2.11.3-py3-none-any.whl.metadata (65 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /opt/conda/lib/python3.11/site-packages (from kserve==0.13.1) (2.9.0.post0)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.0 in /opt/conda/lib/python3.11/site-packages (from kserve==0.13.1) (6.0.2)
# Collecting ray<2.11.0,>=2.10.0 (from ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1)
#   Downloading ray-2.10.0-cp311-cp311-manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: six<2.0.0,>=1.16.0 in /opt/conda/lib/python3.11/site-packages (from kserve==0.13.1) (1.17.0)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /opt/conda/lib/python3.11/site-packages (from kserve==0.13.1) (0.9.0)
# Collecting timing-asgi<0.4.0,>=0.3.0 (from kserve==0.13.1)
#   Downloading timing_asgi-0.3.1-py3-none-any.whl.metadata (3.7 kB)
# Collecting uvicorn<0.22.0,>=0.21.1 (from uvicorn[standard]<0.22.0,>=0.21.1->kserve==0.13.1)
#   Downloading uvicorn-0.21.1-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: cachetools<6,>=5.0.0 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==2.15.1->mlflow==2.15.1) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==2.15.1->mlflow==2.15.1) (8.1.8)
# Requirement already satisfied: cloudpickle<4 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==2.15.1->mlflow==2.15.1) (3.1.1)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==2.15.1->mlflow==2.15.1)
#   Downloading databricks_sdk-0.50.0-py3-none-any.whl.metadata (38 kB)
# Collecting entrypoints<1 (from mlflow-skinny==2.15.1->mlflow==2.15.1)
#   Downloading entrypoints-0.4-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==2.15.1->mlflow==2.15.1) (3.1.44)
# Collecting importlib-metadata!=4.7.0,<8,>=3.7.0 (from mlflow-skinny==2.15.1->mlflow==2.15.1)
#   Downloading importlib_metadata-7.2.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==2.15.1->mlflow==2.15.1)
#   Downloading opentelemetry_api-1.32.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==2.15.1->mlflow==2.15.1)
#   Downloading opentelemetry_sdk-1.32.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: packaging<25 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==2.15.1->mlflow==2.15.1) (24.2)
# Requirement already satisfied: pytz<2025 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==2.15.1->mlflow==2.15.1) (2024.1)
# Requirement already satisfied: requests<3,>=2.17.3 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==2.15.1->mlflow==2.15.1) (2.32.3)
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny==2.15.1->mlflow==2.15.1)
#   Downloading sqlparse-0.5.3-py3-none-any.whl.metadata (3.9 kB)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow==2.15.1)
#   Downloading mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.12 in /opt/conda/lib/python3.11/site-packages (from alembic!=1.10.0,<2->mlflow==2.15.1) (4.12.2)
# Collecting deprecation<3.0,>=2.0 (from cloudevents<2.0.0,>=1.6.2->kserve==0.13.1)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/conda/lib/python3.11/site-packages (from docker<8,>=4.0.0->mlflow==2.15.1) (1.26.20)
# Collecting starlette<0.37.0,>=0.36.3 (from fastapi<0.110.0,>=0.109.1->kserve==0.13.1)
#   Downloading starlette-0.36.3-py3-none-any.whl.metadata (5.9 kB)
# Collecting Werkzeug>=3.1 (from Flask<4->mlflow==2.15.1)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting itsdangerous>=2.2 (from Flask<4->mlflow==2.15.1)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting blinker>=1.9 (from Flask<4->mlflow==2.15.1)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow==2.15.1)
#   Downloading graphql_core-3.2.6-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow==2.15.1)
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.11/site-packages (from httpx<0.27.0,>=0.26.0->kserve==0.13.1) (4.8.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from httpx<0.27.0,>=0.26.0->kserve==0.13.1) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.11/site-packages (from httpx<0.27.0,>=0.26.0->kserve==0.13.1) (1.0.7)
# Requirement already satisfied: idna in /opt/conda/lib/python3.11/site-packages (from httpx<0.27.0,>=0.26.0->kserve==0.13.1) (3.10)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.11/site-packages (from httpx<0.27.0,>=0.26.0->kserve==0.13.1) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.11/site-packages (from httpcore==1.*->httpx<0.27.0,>=0.26.0->kserve==0.13.1) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from Jinja2<4,>=2.11->mlflow==2.15.1) (3.0.2)
# Requirement already satisfied: google-auth>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from kubernetes>=23.3.0->kserve==0.13.1) (2.38.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /opt/conda/lib/python3.11/site-packages (from kubernetes>=23.3.0->kserve==0.13.1) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /opt/conda/lib/python3.11/site-packages (from kubernetes>=23.3.0->kserve==0.13.1) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /opt/conda/lib/python3.11/site-packages (from kubernetes>=23.3.0->kserve==0.13.1) (3.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4->mlflow==2.15.1) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4->mlflow==2.15.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4->mlflow==2.15.1) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4->mlflow==2.15.1) (1.4.7)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4->mlflow==2.15.1) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4->mlflow==2.15.1) (3.2.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas<3->mlflow==2.15.1) (2025.1)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>1.0->kserve==0.13.1)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.1 (from pydantic<3,>1.0->kserve==0.13.1)
#   Downloading pydantic_core-2.33.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<3,>1.0->kserve==0.13.1)
#   Downloading typing_inspection-0.4.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from ray<2.11.0,>=2.10.0->ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1) (3.13.1)
# Requirement already satisfied: jsonschema in /opt/conda/lib/python3.11/site-packages (from ray<2.11.0,>=2.10.0->ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1) (4.23.0)
# Collecting msgpack<2.0.0,>=1.0.0 (from ray<2.11.0,>=2.10.0->ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1)
#   Downloading msgpack-1.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.4 kB)
# Collecting aiosignal (from ray<2.11.0,>=2.10.0->ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1)
#   Downloading aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting frozenlist (from ray<2.11.0,>=2.10.0->ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1)
#   Downloading frozenlist-1.6.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Collecting aiohttp-cors (from ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1)
#   Downloading aiohttp_cors-0.8.1-py3-none-any.whl.metadata (20 kB)
# Collecting watchfiles (from ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1)
#   Downloading watchfiles-1.0.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting smart-open (from ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1)
#   Downloading smart_open-7.1.0-py3-none-any.whl.metadata (24 kB)
# Collecting colorful (from ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1)
#   Downloading colorful-0.5.6-py2.py3-none-any.whl.metadata (16 kB)
# Collecting opencensus (from ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1)
#   Downloading opencensus-0.11.4-py2.py3-none-any.whl.metadata (12 kB)
# Collecting py-spy>=0.2.0 (from ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1)
#   Downloading py_spy-0.4.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (16 kB)
# Collecting virtualenv!=20.21.1,>=20.0.24 (from ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1)
#   Downloading virtualenv-20.30.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting aiohttp>=3.7 (from ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1)
#   Downloading aiohttp-3.11.18-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn<2->mlflow==2.15.1) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn<2->mlflow==2.15.1) (3.5.0)
# Collecting greenlet>=1 (from sqlalchemy<3,>=1.4.0->mlflow==2.15.1)
#   Downloading greenlet-3.2.1-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (4.1 kB)
# Collecting httptools>=0.5.0 (from uvicorn[standard]<0.22.0,>=0.21.1->kserve==0.13.1)
#   Downloading httptools-0.6.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]<0.22.0,>=0.21.1->kserve==0.13.1)
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]<0.22.0,>=0.21.1->kserve==0.13.1)
#   Downloading uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]<0.22.0,>=0.21.1->kserve==0.13.1)
#   Downloading websockets-15.0.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp>=3.7->ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp>=3.7->ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1) (25.1.0)
# Collecting multidict<7.0,>=4.5 (from aiohttp>=3.7->ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1)
#   Downloading multidict-6.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp>=3.7->ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1)
#   Downloading propcache-0.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp>=3.7->ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1)
#   Downloading yarl-1.20.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (72 kB)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.11/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.15.1->mlflow==2.15.1) (4.0.12)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=23.3.0->kserve==0.13.1) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=23.3.0->kserve==0.13.1) (4.9)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.11/site-packages (from importlib-metadata!=4.7.0,<8,>=3.7.0->mlflow-skinny==2.15.1->mlflow==2.15.1) (3.21.0)
# Collecting deprecated>=1.2.6 (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.15.1->mlflow==2.15.1)
#   Downloading Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Collecting opentelemetry-semantic-conventions==0.53b1 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.15.1->mlflow==2.15.1)
#   Downloading opentelemetry_semantic_conventions-0.53b1-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.15.1->mlflow==2.15.1) (3.4.1)
# Collecting distlib<1,>=0.3.7 (from virtualenv!=20.21.1,>=20.0.24->ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1)
#   Downloading distlib-0.3.9-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /opt/conda/lib/python3.11/site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1) (4.3.6)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.11/site-packages (from jsonschema->ray<2.11.0,>=2.10.0->ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.11/site-packages (from jsonschema->ray<2.11.0,>=2.10.0->ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from jsonschema->ray<2.11.0,>=2.10.0->ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1) (0.22.3)
# Collecting opencensus-context>=0.1.3 (from opencensus->ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1)
#   Downloading opencensus_context-0.1.3-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from opencensus->ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1) (2.24.1)
# Collecting wrapt (from smart-open->ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1)
#   Downloading wrapt-1.17.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.15.1->mlflow==2.15.1) (5.0.2)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /opt/conda/lib/python3.11/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1) (1.67.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /opt/conda/lib/python3.11/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[serve]<2.11.0,>=2.10.0->kserve==0.13.1) (1.26.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /opt/conda/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=23.3.0->kserve==0.13.1) (0.6.1)
# Downloading mlflow-2.15.1-py3-none-any.whl (26.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.3/26.3 MB 17.7 MB/s eta 0:00:00a 0:00:01
# Downloading kserve-0.13.1-py3-none-any.whl (452 kB)
# Downloading mlflow_skinny-2.15.1-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 32.7 MB/s eta 0:00:00
# Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Downloading alembic-1.15.2-py3-none-any.whl (231 kB)
# Downloading cloudevents-1.11.0-py3-none-any.whl (55 kB)
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
# Downloading fastapi-0.109.2-py3-none-any.whl (92 kB)
# Downloading flask-3.1.0-py3-none-any.whl (102 kB)
# Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
# Downloading grpcio-1.71.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 33.3 MB/s eta 0:00:00
# Downloading gunicorn-22.0.0-py3-none-any.whl (84 kB)
# Downloading httpx-0.26.0-py3-none-any.whl (75 kB)
# Downloading markdown-3.8-py3-none-any.whl (106 kB)
# Downloading orjson-3.10.16-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (132 kB)
# Downloading prometheus_client-0.20.0-py3-none-any.whl (54 kB)
# Downloading protobuf-3.20.3-py2.py3-none-any.whl (162 kB)
# Downloading psutil-5.9.8-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
# Downloading pyarrow-15.0.2-cp311-cp311-manylinux_2_28_x86_64.whl (38.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.3/38.3 MB 25.6 MB/s eta 0:00:0000:0100:01
# Downloading pydantic-2.11.3-py3-none-any.whl (443 kB)
# Downloading pydantic_core-2.33.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 31.4 MB/s eta 0:00:00
# Downloading querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Downloading ray-2.10.0-cp311-cp311-manylinux2014_x86_64.whl (65.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.6/65.6 MB 6.7 MB/s eta 0:00:0000:0100:01
# Downloading sqlalchemy-2.0.40-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 33.4 MB/s eta 0:00:00
# Downloading timing_asgi-0.3.1-py3-none-any.whl (5.6 kB)
# Downloading uvicorn-0.21.1-py3-none-any.whl (57 kB)
# Downloading aiohttp-3.11.18-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 29.5 MB/s eta 0:00:00
# Downloading aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading databricks_sdk-0.50.0-py3-none-any.whl (692 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 692.3/692.3 kB 21.1 MB/s eta 0:00:00
# Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Downloading entrypoints-0.4-py3-none-any.whl (5.3 kB)
# Downloading frozenlist-1.6.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (313 kB)
# Downloading graphql_core-3.2.6-py3-none-any.whl (203 kB)
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading greenlet-3.2.1-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (583 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 583.9/583.9 kB 17.0 MB/s eta 0:00:00
# Downloading httptools-0.6.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (459 kB)
# Downloading importlib_metadata-7.2.1-py3-none-any.whl (25 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading msgpack-1.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (403 kB)
# Downloading opentelemetry_api-1.32.1-py3-none-any.whl (65 kB)
# Downloading opentelemetry_sdk-1.32.1-py3-none-any.whl (118 kB)
# Downloading opentelemetry_semantic_conventions-0.53b1-py3-none-any.whl (188 kB)
# Downloading py_spy-0.4.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 32.9 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Downloading sqlparse-0.5.3-py3-none-any.whl (44 kB)
# Downloading starlette-0.36.3-py3-none-any.whl (71 kB)
# Downloading typing_inspection-0.4.0-py3-none-any.whl (14 kB)
# Downloading uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 21.6 MB/s eta 0:00:00
# Downloading virtualenv-20.30.0-py3-none-any.whl (4.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 32.5 MB/s eta 0:00:00
# Downloading watchfiles-1.0.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (454 kB)
# Downloading websockets-15.0.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (182 kB)
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Downloading aiohttp_cors-0.8.1-py3-none-any.whl (25 kB)
# Downloading colorful-0.5.6-py2.py3-none-any.whl (201 kB)
# Downloading mako-1.3.10-py3-none-any.whl (78 kB)
# Downloading opencensus-0.11.4-py2.py3-none-any.whl (128 kB)
# Downloading smart_open-7.1.0-py3-none-any.whl (61 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Downloading distlib-0.3.9-py2.py3-none-any.whl (468 kB)
# Downloading multidict-6.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (223 kB)
# Downloading opencensus_context-0.1.3-py2.py3-none-any.whl (5.1 kB)
# Downloading propcache-0.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (232 kB)
# Downloading wrapt-1.17.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (83 kB)
# Downloading yarl-1.20.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (358 kB)
# Installing collected packages: py-spy, opencensus-context, distlib, colorful, wrapt, Werkzeug, websockets, virtualenv, uvloop, uvicorn, typing-inspection, timing-asgi, tenacity, sqlparse, querystring-parser, python-dotenv, pydantic-core, pyarrow, psutil, protobuf, propcache, prometheus-client, orjson, multidict, msgpack, markdown, Mako, itsdangerous, importlib-metadata, httptools, gunicorn, grpcio, greenlet, graphql-core, frozenlist, entrypoints, deprecation, blinker, annotated-types, aiohappyeyeballs, yarl, watchfiles, starlette, sqlalchemy, smart-open, pydantic, httpx, graphql-relay, Flask, docker, deprecated, cloudevents, aiosignal, opentelemetry-api, graphene, fastapi, databricks-sdk, alembic, aiohttp, ray, opentelemetry-semantic-conventions, opencensus, aiohttp-cors, opentelemetry-sdk, mlflow-skinny, kserve, mlflow
#   Attempting uninstall: psutil
#     Found existing installation: psutil 6.1.1
#     Uninstalling psutil-6.1.1:
#       Successfully uninstalled psutil-6.1.1
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.6
#     Uninstalling protobuf-4.25.6:
#       Successfully uninstalled protobuf-4.25.6
#   Attempting uninstall: prometheus-client
#     Found existing installation: prometheus_client 0.21.1
#     Uninstalling prometheus_client-0.21.1:
#       Successfully uninstalled prometheus_client-0.21.1
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib_metadata 8.6.1
#     Uninstalling importlib_metadata-8.6.1:
#       Successfully uninstalled importlib_metadata-8.6.1
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.28.1
#     Uninstalling httpx-0.28.1:
#       Successfully uninstalled httpx-0.28.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kfp 2.11.0 requires protobuf<5,>=4.21.1, but you have protobuf 3.20.3 which is incompatible.
# kfp-pipeline-spec 0.6.0 requires protobuf<5,>=4.21.1, but you have protobuf 3.20.3 which is incompatible.
# Successfully installed Flask-3.1.0 Mako-1.3.10 Werkzeug-3.1.3 aiohappyeyeballs-2.6.1 aiohttp-3.11.18 aiohttp-cors-0.8.1 aiosignal-1.3.2 alembic-1.15.2 annotated-types-0.7.0 blinker-1.9.0 cloudevents-1.11.0 colorful-0.5.6 databricks-sdk-0.50.0 deprecated-1.2.18 deprecation-2.1.0 distlib-0.3.9 docker-7.1.0 entrypoints-0.4 fastapi-0.109.2 frozenlist-1.6.0 graphene-3.4.3 graphql-core-3.2.6 graphql-relay-3.2.0 greenlet-3.2.1 grpcio-1.71.0 gunicorn-22.0.0 httptools-0.6.4 httpx-0.26.0 importlib-metadata-7.2.1 itsdangerous-2.2.0 kserve-0.13.1 markdown-3.8 mlflow-2.15.1 mlflow-skinny-2.15.1 msgpack-1.1.0 multidict-6.4.3 opencensus-0.11.4 opencensus-context-0.1.3 opentelemetry-api-1.32.1 opentelemetry-sdk-1.32.1 opentelemetry-semantic-conventions-0.53b1 orjson-3.10.16 prometheus-client-0.20.0 propcache-0.3.1 protobuf-3.20.3 psutil-5.9.8 py-spy-0.4.0 pyarrow-15.0.2 pydantic-2.11.3 pydantic-core-2.33.1 python-dotenv-1.1.0 querystring-parser-1.2.4 ray-2.10.0 smart-open-7.1.0 sqlalchemy-2.0.40 sqlparse-0.5.3 starlette-0.36.3 tenacity-9.1.2 timing-asgi-0.3.1 typing-inspection-0.4.0 uvicorn-0.21.1 uvloop-0.21.0 virtualenv-20.30.0 watchfiles-1.0.5 websockets-15.0.1 wrapt-1.17.2 yarl-1.20.0

# %% [markdown]
#  ## Import the necessary components

# %%
import kfp
import mlflow
import os
import requests

from kfp.dsl import Input, Model, component
from kfp.dsl import InputPath, OutputPath, pipeline, component
from kserve import KServeClient
from mlflow.tracking import MlflowClient
from tenacity import retry, stop_after_attempt, wait_exponential

# %% [markdown]
# ## Ingest your data
# Create a component that downloads the dataset, imports it as a .csv file and then saves it at a specified path.

# %%
@component(
    base_image="python:3.11",
    packages_to_install=["requests==2.32.3", "pandas==2.2.2"]
)
def download_dataset(url: str, dataset_path: OutputPath('Dataset')) -> None:
    import requests
    import pandas as pd

    response = requests.get(url)
    response.raise_for_status()

    from io import StringIO
    dataset = pd.read_csv(StringIO(response.text), header=0, sep=";")

    dataset.to_csv(dataset_path, index=False)

# %% [markdown]
# ## Process the data
# Create a component that preprocesses the dataset and saves it as an Apache Parquet file for a more efficient storage.

# %%
@component(
    base_image="python:3.11",
    packages_to_install=["pandas==2.2.2", "pyarrow==15.0.2"]
)
def preprocess_dataset(dataset: InputPath('Dataset'), output_file: OutputPath('Dataset')) -> None:
    import pandas as pd
    
    df = pd.read_csv(dataset, header=0)
    df.columns = [c.lower().replace(" ", "_") for c in df.columns]
    df.to_parquet(output_file)

# %% [markdown]
# ## Train an ML model
# Now that the dataset is preprocessed, you can write a component that:
# * splits the dataset into training and testing data
# * trains an ElasticNet regression model
# * logs all model artefacts to MLflow

# %%
@component(
    base_image="python:3.11",
    packages_to_install=["pandas==2.2.2", "scikit-learn==1.5.1", "mlflow==2.15.1", "pyarrow==15.0.2", "boto3==1.34.162"]
)
def train_model(dataset: InputPath('Dataset'), run_name: str, model_name: str) -> str:
    import os
    import mlflow
    import pandas as pd
    from sklearn.linear_model import ElasticNet
    from sklearn.model_selection import train_test_split

    df = pd.read_parquet(dataset)
    
    target_column = "quality"

    train_x, test_x, train_y, test_y = train_test_split(
        df.drop(columns=[target_column]),
        df[target_column], test_size=0.25,
        random_state=42, stratify=df[target_column]
    )

    mlflow.sklearn.autolog()
    
    with mlflow.start_run(run_name=run_name) as run:
        mlflow.set_tag("author", "kf-testing")
        lr = ElasticNet(alpha=0.5, l1_ratio=0.5, random_state=42)
        lr.fit(train_x, train_y)
        mlflow.sklearn.log_model(lr, "model", registered_model_name=model_name)
        
        model_uri = f"{run.info.artifact_uri}/model"
        print(model_uri)
        return model_uri

# %% [markdown]
# ## Deploy the ML model
# After the model has been trained, you can create a KServe inference service to enable scalable and performant model inference using HTTP requests. See [KServe documentation](https://kserve.github.io/website/0.13/get_started/first_isvc/) for more details.
# Write a component that creates a KServe inference service and returns its URL.

# %%
@component(
    base_image="python:3.11",
    packages_to_install=["kserve==0.13.1", "kubernetes==26.1.0", "tenacity==9.0.0"]
)
def deploy_model_with_kserve(model_uri: str, isvc_name: str) -> str:
    from kubernetes.client import V1ObjectMeta
    from kserve import (
        constants,
        KServeClient,
        V1beta1InferenceService,
        V1beta1InferenceServiceSpec,
        V1beta1PredictorSpec,
        V1beta1SKLearnSpec,
    )
    from tenacity import retry, wait_exponential, stop_after_attempt

    isvc = V1beta1InferenceService(
        api_version=constants.KSERVE_V1BETA1,
        kind=constants.KSERVE_KIND,
        metadata=V1ObjectMeta(
            name=isvc_name,
            annotations={"sidecar.istio.io/inject": "false"},
        ),
        spec=V1beta1InferenceServiceSpec(
            predictor=V1beta1PredictorSpec(
                service_account_name="kserve-controller-s3",
                sklearn=V1beta1SKLearnSpec(
                    storage_uri=model_uri
                )
            )
        )
    )
    
    client = KServeClient()
    client.create(isvc)

    @retry(
        wait=wait_exponential(multiplier=2, min=1, max=10),
        stop=stop_after_attempt(30),
        reraise=True,
    )
    def assert_isvc_created(client, isvc_name):
        assert client.is_isvc_ready(isvc_name), f"Failed to create Inference Service {isvc_name}."

    assert_isvc_created(client, isvc_name)
    isvc_resp = client.get(isvc_name)
    isvc_url = isvc_resp['status']['address']['url']
    print("Inference URL:", isvc_url)
    
    return isvc_url

# %% [markdown]
# ## Create a pipeline
# Create a pipeline that combines all the components you defined in the previous sections.

# %%
ISVC_NAME = "wine-regressor4"
MLFLOW_RUN_NAME = "elastic_net_models"
MLFLOW_MODEL_NAME = "wine-elasticnet"

mlflow_tracking_uri = os.getenv('MLFLOW_TRACKING_URI')
mlflow_s3_endpoint_url = os.getenv('MLFLOW_S3_ENDPOINT_URL')
aws_access_key_id = os.getenv('AWS_ACCESS_KEY_ID')
aws_secret_access_key = os.getenv('AWS_SECRET_ACCESS_KEY')
print("mlflow_tracking_uri: ", mlflow_tracking_uri)
print("mlflow_s3_endpoint_url: ", mlflow_s3_endpoint_url)
print("aws_access_key_id: ", aws_access_key_id)
print("aws_secret_access_key: ", aws_secret_access_key)

@pipeline(name='download-preprocess-train-deploy-pipeline')
def download_preprocess_train_deploy_pipeline(url: str):
    download_task = download_dataset(url=url)
    
    preprocess_task = preprocess_dataset(
        dataset=download_task.outputs['dataset_path']
    )
    
    train_task = train_model(
        dataset=preprocess_task.outputs['output_file'], run_name=MLFLOW_RUN_NAME, model_name=MLFLOW_MODEL_NAME
    ).set_env_variable(name='MLFLOW_TRACKING_URI', value=mlflow_tracking_uri)\
     .set_env_variable(name='MLFLOW_S3_ENDPOINT_URL', value=mlflow_s3_endpoint_url)\
     .set_env_variable(name='AWS_ACCESS_KEY_ID', value=aws_access_key_id)\
     .set_env_variable(name='AWS_SECRET_ACCESS_KEY', value=aws_secret_access_key)
    
    deploy_task = deploy_model_with_kserve(
        model_uri=train_task.output, isvc_name=ISVC_NAME
    ).set_env_variable(name='AWS_SECRET_ACCESS_KEY', value=aws_secret_access_key)
# Out:
# mlflow_tracking_uri:  http://mlflow-server.kubeflow.svc.cluster.local:5000
# mlflow_s3_endpoint_url:  http://mlflow-minio.kubeflow:9000
# aws_access_key_id:  minio
# aws_secret_access_key:  O99F5MNNAZ7KJJ878CZ5ZFQAWUVCE8

# %% [markdown]
# ## Execute the pipeline
# To execute the pipeline, you first have to initialise a Kubeflow Pipelines (KFP) client to interact with the Kubeflow Pipelines API. Then, you must compile the pipeline to a compatible YAML file and create a run from the produced YAML file.

# %%
client = kfp.Client()

url = 'https://raw.githubusercontent.com/canonical/kubeflow-examples/main/e2e-wine-kfp-mlflow/winequality-red.csv'

kfp.compiler.Compiler().compile(download_preprocess_train_deploy_pipeline, 'download_preprocess_train_deploy_pipeline.yaml')

run = client.create_run_from_pipeline_func(download_preprocess_train_deploy_pipeline, arguments={'url': url}, enable_caching=False)
# Out:
# /opt/conda/lib/python3.11/site-packages/kfp/client/client.py:159: FutureWarning: This client only works with Kubeflow Pipeline v2.0.0-beta.2 and later versions.
#   warnings.warn(
# <a href="/pipeline/#/experiments/details/fe0535ef-b7df-4653-8f19-cb680fb9f941" target="_blank" >Experiment details</a>.
# <a href="/pipeline/#/runs/details/70eb09d8-65d5-4fe8-8d2a-9b4d96d9bf0e" target="_blank" >Run details</a>.
